# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1. Load the data into the pandas environment and identify some basic details of the dataset.

# %%
data=pd.read_csv(r'C:\Users\Anila John\Downloads\employee.csv')
data
# Out:
#             name   age   income gender  department grade  performance_score
# 0    Allen Smith  45.0      NaN    NaN  Operations    G3                723
# 1        S Kumar   NaN  16000.0      F     Finance    G0                520
# 2    Jack Morgan  32.0  35000.0      M     Finance    G2                674
# 3      Ying Chin  45.0  65000.0      F       Sales    G3                556
# 4  Dheeraj Patel  30.0  42000.0      F  Operations    G2                711
# 5  Satyam Sharma   NaN  62000.0    NaN       Sales    G3                649
# 6   James Authur  54.0      NaN      F  Operations    G3                 53
# 7     Josh Wills  54.0  52000.0      F     Finance    G3                901
# 8       Leo Duck  23.0  98000.0      M       Sales    G4                709

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               9 non-null      object
#  1   age                7 non-null      float64
#  2   income             7 non-null      float64
#  3   gender             7 non-null      object
#  4   department         9 non-null      object
#  5   grade              9 non-null      object
#  6   performance_score  9 non-null      int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 632.0+ bytes

# %%
data.describe()
# Out:
#              age        income  performance_score
# count   7.000000      7.000000           9.000000
# mean   40.428571  52857.142857         610.666667
# std    12.204605  26028.372797         235.671912
# min    23.000000  16000.000000          53.000000
# 25%    31.000000  38500.000000         556.000000
# 50%    45.000000  52000.000000         674.000000
# 75%    49.500000  63500.000000         711.000000
# max    54.000000  98000.000000         901.000000

# %%
data.isna().sum()
# Out:
# name                 0
# age                  2
# income               2
# gender               2
# department           0
# grade                0
# performance_score    0
# dtype: int64

# %%
data.dtypes
# Out:
# name                  object
# age                  float64
# income               float64
# gender                object
# department            object
# grade                 object
# performance_score      int64
# dtype: object

# %% [markdown]
# ### 2. Reset the index as "name".

# %%
data.set_index(data['name'], inplace=True)
data
# Out:
#                         name   age   income gender  department grade  \
# name
# Allen Smith      Allen Smith  45.0      NaN    NaN  Operations    G3
# S Kumar              S Kumar   NaN  16000.0      F     Finance    G0
# Jack Morgan      Jack Morgan  32.0  35000.0      M     Finance    G2
# Ying Chin          Ying Chin  45.0  65000.0      F       Sales    G3
# Dheeraj Patel  Dheeraj Patel  30.0  42000.0      F  Operations    G2
# Satyam Sharma  Satyam Sharma   NaN  62000.0    NaN       Sales    G3
# James Authur    James Authur  54.0      NaN      F  Operations    G3
# Josh Wills        Josh Wills  54.0  52000.0      F     Finance    G3
# Leo Duck            Leo Duck  23.0  98000.0      M       Sales    G4
#
#                performance_score
# name
# Allen Smith                  723
# S Kumar                      520
# Jack Morgan                  674
# Ying Chin                    556
# Dheeraj Patel                711
# Satyam Sharma                649
# ...

# %% [markdown]
# ### 3. Select rows for specific names Jack Morgan and Josh wills.

# %%
data.loc[['Jack Morgan', 'Josh Wills']]
# Out:
#                     name   age   income gender department grade  \
# name
# Jack Morgan  Jack Morgan  32.0  35000.0      M    Finance    G2
# Josh Wills    Josh Wills  54.0  52000.0      F    Finance    G3
#
#              performance_score
# name
# Jack Morgan                674
# Josh Wills                 901

# %% [markdown]
# ### 4. Select data for multiple values "Sales" and “Finance”.

# %%
data.loc[(data['department']=='Sales')|(data['department']=='Finance')]
# Out:
#                         name   age   income gender department grade  \
# name
# S Kumar              S Kumar   NaN  16000.0      F    Finance    G0
# Jack Morgan      Jack Morgan  32.0  35000.0      M    Finance    G2
# Ying Chin          Ying Chin  45.0  65000.0      F      Sales    G3
# Satyam Sharma  Satyam Sharma   NaN  62000.0    NaN      Sales    G3
# Josh Wills        Josh Wills  54.0  52000.0      F    Finance    G3
# Leo Duck            Leo Duck  23.0  98000.0      M      Sales    G4
#
#                performance_score
# name
# S Kumar                      520
# Jack Morgan                  674
# Ying Chin                    556
# Satyam Sharma                649
# Josh Wills                   901
# Leo Duck                     709

# %% [markdown]
# ### 5. Display employee who has more than 700 performance score.

# %%
data[data['performance_score']>700]
# Out:
#                         name   age   income gender  department grade  \
# name
# Allen Smith      Allen Smith  45.0      NaN    NaN  Operations    G3
# Dheeraj Patel  Dheeraj Patel  30.0  42000.0      F  Operations    G2
# Josh Wills        Josh Wills  54.0  52000.0      F     Finance    G3
# Leo Duck            Leo Duck  23.0  98000.0      M       Sales    G4
#
#                performance_score
# name
# Allen Smith                  723
# Dheeraj Patel                711
# Josh Wills                   901
# Leo Duck                     709

# %% [markdown]
# ### 6. Display employee who has more than 500 and less than 700 performance score.

# %%
data[(data['performance_score']>500) & (data['performance_score']<700)]
# Out:
#                         name   age   income gender department grade  \
# name
# S Kumar              S Kumar   NaN  16000.0      F    Finance    G0
# Jack Morgan      Jack Morgan  32.0  35000.0      M    Finance    G2
# Ying Chin          Ying Chin  45.0  65000.0      F      Sales    G3
# Satyam Sharma  Satyam Sharma   NaN  62000.0    NaN      Sales    G3
#
#                performance_score
# name
# S Kumar                      520
# Jack Morgan                  674
# Ying Chin                    556
# Satyam Sharma                649

# %% [markdown]
# ### 7. Check and handle missing values in the dataset.

# %%
data.isna().sum()
# Out:
# name                 0
# age                  2
# income               2
# gender               2
# department           0
# grade                0
# performance_score    0
# dtype: int64

# %%
data.isna()
# Out:
#                 name    age  income  gender  department  grade  \
# name
# Allen Smith    False  False    True    True       False  False
# S Kumar        False   True   False   False       False  False
# Jack Morgan    False  False   False   False       False  False
# Ying Chin      False  False   False   False       False  False
# Dheeraj Patel  False  False   False   False       False  False
# Satyam Sharma  False   True   False    True       False  False
# James Authur   False  False    True   False       False  False
# Josh Wills     False  False   False   False       False  False
# Leo Duck       False  False   False   False       False  False
#
#                performance_score
# name
# Allen Smith                False
# S Kumar                    False
# Jack Morgan                False
# Ying Chin                  False
# Dheeraj Patel              False
# Satyam Sharma              False
# James Authur               False
# Josh Wills                 False
# ...

# %%
data.dtypes
# Out:
# name                  object
# age                  float64
# income               float64
# gender                object
# department            object
# grade                 object
# performance_score      int64
# dtype: object

# %%
for i in ['age', 'income']:
    data[i]=data[i].fillna(data[i].median())
data
# Out:
#                         name   age   income gender  department grade  \
# name
# Allen Smith      Allen Smith  45.0  52000.0    NaN  Operations    G3
# S Kumar              S Kumar  45.0  16000.0      F     Finance    G0
# Jack Morgan      Jack Morgan  32.0  35000.0      M     Finance    G2
# Ying Chin          Ying Chin  45.0  65000.0      F       Sales    G3
# Dheeraj Patel  Dheeraj Patel  30.0  42000.0      F  Operations    G2
# Satyam Sharma  Satyam Sharma  45.0  62000.0    NaN       Sales    G3
# James Authur    James Authur  54.0  52000.0      F  Operations    G3
# Josh Wills        Josh Wills  54.0  52000.0      F     Finance    G3
# Leo Duck            Leo Duck  23.0  98000.0      M       Sales    G4
#
#                performance_score
# name
# Allen Smith                  723
# S Kumar                      520
# Jack Morgan                  674
# Ying Chin                    556
# Dheeraj Patel                711
# Satyam Sharma                649
# ...

# %%
data['gender'] = data['gender'].fillna(data['gender'].mode()[0])
data
# Out:
#                         name   age   income gender  department grade  \
# name
# Allen Smith      Allen Smith  45.0  52000.0      F  Operations    G3
# S Kumar              S Kumar  45.0  16000.0      F     Finance    G0
# Jack Morgan      Jack Morgan  32.0  35000.0      M     Finance    G2
# Ying Chin          Ying Chin  45.0  65000.0      F       Sales    G3
# Dheeraj Patel  Dheeraj Patel  30.0  42000.0      F  Operations    G2
# Satyam Sharma  Satyam Sharma  45.0  62000.0      F       Sales    G3
# James Authur    James Authur  54.0  52000.0      F  Operations    G3
# Josh Wills        Josh Wills  54.0  52000.0      F     Finance    G3
# Leo Duck            Leo Duck  23.0  98000.0      M       Sales    G4
#
#                performance_score
# name
# Allen Smith                  723
# S Kumar                      520
# Jack Morgan                  674
# Ying Chin                    556
# Dheeraj Patel                711
# Satyam Sharma                649
# ...

# %%
data.isna().sum()
# Out:
# name                 0
# age                  0
# income               0
# gender               0
# department           0
# grade                0
# performance_score    0
# dtype: int64

# %% [markdown]
# ### 8. Check the outliers and handle outliers in performance score using Percentiles.

# %%
plt.figure(figsize=(8,6))
plt.boxplot(data['performance_score'])
plt.title('Box plot of Performance score')
plt.show()

# %%
Q1=np.percentile(data['performance_score'], 25, interpolation='midpoint')
Q2=np.percentile(data['performance_score'], 50, interpolation='midpoint')
Q3=np.percentile(data['performance_score'], 75, interpolation='midpoint')
IQR=Q3-Q1
low_limit=Q1-1.5*IQR
up_limit=Q3+1.5*IQR
print("Q1=",Q1)
print("Q2=",Q2)
print("Q3=",Q3)
print("IQR=",IQR)
print("lower_limit=",low_limit)
print("upper_limit=",up_limit)
# Out:
# Q1= 556.0
# Q2= 674.0
# Q3= 711.0
# IQR= 155.0
# lower_limit= 323.5
# upper_limit= 943.5

# %%
outlier=[]
for x in data['performance_score']:
    if((x>up_lim)or(x<low_lim)):
        outlier.append(x)
outlier
# Out:
# [53]

# %%
ind1 = data['performance_score']<low_limit
data.loc[ind1].index
# Out:
# Index(['James Authur'], dtype='object', name='name')

# %%
data.drop(['James Authur'], inplace=True)

# %%
data
# Out:
#                         name   age   income gender  department grade  \
# name
# Allen Smith      Allen Smith  45.0  52000.0      F  Operations    G3
# S Kumar              S Kumar  45.0  16000.0      F     Finance    G0
# Jack Morgan      Jack Morgan  32.0  35000.0      M     Finance    G2
# Ying Chin          Ying Chin  45.0  65000.0      F       Sales    G3
# Dheeraj Patel  Dheeraj Patel  30.0  42000.0      F  Operations    G2
# Satyam Sharma  Satyam Sharma  45.0  62000.0      F       Sales    G3
# Josh Wills        Josh Wills  54.0  52000.0      F     Finance    G3
# Leo Duck            Leo Duck  23.0  98000.0      M       Sales    G4
#
#                performance_score
# name
# Allen Smith                  723
# S Kumar                      520
# Jack Morgan                  674
# Ying Chin                    556
# Dheeraj Patel                711
# Satyam Sharma                649
# Josh Wills                   901
# Leo Duck                     709

# %% [markdown]
# ### 9. Check the gender column and do Dummy encoding.

# %%
data['gender']
# Out:
# name
# Allen Smith      F
# S Kumar          F
# Jack Morgan      M
# Ying Chin        F
# Dheeraj Patel    F
# Satyam Sharma    F
# Josh Wills       F
# Leo Duck         M
# Name: gender, dtype: object

# %%
data['gender'].nunique()
# Out:
# 2

# %%
dummy = pd.get_dummies(data['gender'], prefix='gender', columns='gender_male', drop_first=True)
dummy
# Out:
#                gender_M
# name
# Allen Smith           0
# S Kumar               0
# Jack Morgan           1
# Ying Chin             0
# Dheeraj Patel         0
# Satyam Sharma         0
# Josh Wills            0
# Leo Duck              1

# %% [markdown]
# ### 10.Do the standard scaling on the feature performance score.

# %%
data['performance_score']
# Out:
# name
# Allen Smith      723
# S Kumar          520
# Jack Morgan      674
# Ying Chin        556
# Dheeraj Patel    711
# Satyam Sharma    649
# Josh Wills       901
# Leo Duck         709
# Name: performance_score, dtype: int64

# %%
data['performance_score'].describe()
# Out:
# count      8.00000
# mean     680.37500
# std      116.16729
# min      520.00000
# 25%      625.75000
# 50%      691.50000
# 75%      714.00000
# max      901.00000
# Name: performance_score, dtype: float64

# %%
type(data['performance_score'])
# Out:
# pandas.core.series.Series

# %%
arr=np.array(data['performance_score']).reshape(-1, 1)
arr
# Out:
# array([[723],
#        [520],
#        [674],
#        [556],
#        [711],
#        [649],
#        [901],
#        [709]], dtype=int64)

# %%
from sklearn import preprocessing
Std=preprocessing.StandardScaler()
scaled_score=pd.DataFrame(Std.fit_transform(arr),
                                      columns=['performance_score'],
                                     index=data['name'])
scaled_score
# Out:
#                performance_score
# name
# Allen Smith             0.392262
# S Kumar                -1.475872
# Jack Morgan            -0.058667
# Ying Chin              -1.144578
# Dheeraj Patel           0.281831
# Satyam Sharma          -0.288733
# Josh Wills              2.030331
# Leo Duck                0.263425
