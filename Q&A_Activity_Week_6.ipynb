# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_excel(r"C:\Users\Anila John\Downloads\Dataset_w6.xlsx")
data
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0              652864.0                         35530.0
# 1               28748.0                          2930.0
# 2             2381741.0                         41318.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 7 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   country                                     196 non-null    object
#  1   Region                                      196 non-null    object
#  2   Surface area (km2)                          196 non-null    float64
#  3   Population in thousands (2017)              196 non-null    float64
#  4   GDP per capita (current US$)                196 non-null    float64
#  5   Agricultural production index               196 non-null    float64
#  6   International trade: Imports (million US$)  196 non-null    float64
# dtypes: float64(5), object(2)
# memory usage: 10.8+ KB

# %% [markdown]
# ### 1. Find out how many countries are there in the dataset.

# %%
data["country"].count()
# Out:
# 196

# %% [markdown]
# ### 2. Examine the data by using visualizations.

# %%
plt.figure(figsize=(18,14))
plt.subplot(2,2,1)
sns.barplot(x='country',y='Population in thousands (2017)',data=data.sort_values('Population in thousands (2017)',ascending=False).head(10),palette='Set1')
plt.title('Top 10 Countries - Population in thousands (2017)',fontweight='bold',fontsize=15)
plt.xlabel('Country',fontsize=12)
plt.ylabel('Population in thousands (2017)',fontsize=12)
plt.xticks(rotation=90)
plt.grid()
plt.tight_layout()


plt.subplot(2,2,2)
sns.barplot(x='country',y='GDP per capita (current US$)',data=data.sort_values('GDP per capita (current US$)',ascending=False).head(10), palette='Set2')
plt.title('Top 10 Countries - GDP per capita (current US$)',fontweight='bold',fontsize=15)
plt.xlabel("Country",fontsize=12)
plt.ylabel("GDP per capita",fontsize=12)
plt.xticks(rotation=90)
plt.grid()

plt.tight_layout()

plt.subplot(2,2,3)
sns.barplot(x='country',y='Agricultural production index ',data=data.sort_values('Agricultural production index ',ascending=False).head(10), palette='Set3')
plt.title('Top 10 Countries - Agricultural Production Index',fontweight='bold',fontsize=15)
plt.xlabel('Country',fontsize=12)
plt.ylabel('Agricultural production index',fontsize=12)
plt.xticks(rotation=90)
plt.grid()
plt.tight_layout()

plt.subplot(2,2,4)
sns.barplot(x='country',y='International trade: Imports (million US$)',data=data.sort_values('International trade: Imports (million US$)',ascending=False).head(10))
plt.title('Top 10 Countries - International Trade: Imports(million US$)',fontweight='bold',fontsize=15)
plt.xlabel('Country',fontsize=12)
plt.ylabel('International trade: Imports (million US$)',fontsize=12)
plt.xticks(rotation=90)
plt.grid()
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(18,14))
plt.subplot(2,2,1)
sns.barplot(x='country',y='Population in thousands (2017)',data=data.sort_values('Population in thousands (2017)',ascending=True).head(10),palette='Set1')
plt.title('Least 10 Countries - Population in thousands (2017)',fontweight='bold',fontsize=15)
plt.xlabel('Country',fontsize=12)
plt.ylabel('Population in thousands (2017)',fontsize=12)
plt.xticks(rotation=90)
plt.grid()
plt.tight_layout()


plt.subplot(2,2,2)
sns.barplot(x='country',y='GDP per capita (current US$)',data=data.sort_values('GDP per capita (current US$)',ascending=True).head(10), palette='Set2')
plt.title('Least 10 Countries - GDP per capita (current US$)',fontweight='bold',fontsize=15)
plt.xlabel("Country",fontsize=12)
plt.ylabel("GDP per capita",fontsize=12)
plt.xticks(rotation=90)
plt.grid()
plt.tight_layout()

plt.subplot(2,2,3)
sns.barplot(x='country',y='Agricultural production index ',data=data.sort_values('Agricultural production index ',ascending=True).head(10), palette='Set3')
plt.title('Least 10 Countries - Agricultural Production Index',fontweight='bold',fontsize=15)
plt.xlabel('Country',fontsize=12)
plt.ylabel('Agricultural production index',fontsize=12)
plt.xticks(rotation=90)
plt.grid()
plt.tight_layout()

plt.subplot(2,2,4)
sns.barplot(x='country',y='International trade: Imports (million US$)',data=data.sort_values('International trade: Imports (million US$)',ascending=True).head(10))
plt.title('Least 10 Countries - International Trade: Imports(million US$)',fontweight='bold',fontsize=15)
plt.xlabel('Country',fontsize=12)
plt.ylabel('International trade: Imports (million US$)',fontsize=12)
plt.xticks(rotation=90)
plt.grid()
plt.show()
plt.tight_layout()

# %%
plt.figure(figsize=(18,8))
plt.bar(data['Region'],data['Surface area (km2)'],color='purple')
plt.title('Region Vs Surface area',fontweight='bold',fontsize=15)
plt.xticks(rotation=90)
plt.yticks()
plt.xlabel('Region',fontsize=12)
plt.ylabel('Surface area (km2)',fontsize=12)
plt.grid()

# %% [markdown]
# ### 3. Find out how many countries with respect to the region are available in the dataset.

# %%
data.groupby('Region')[['country']].count()
# Out:
#                    country
# Region
# Caribbean               16
# CentralAmerica           8
# CentralAsia              5
# EasternAfrica           17
# EasternAsia              7
# EasternEurope           10
# Melanesia                5
# Micronesia               4
# MiddleAfrica             9
# NorthernAfrica           5
# NorthernAmerica          4
# NorthernEurope          10
# Oceania                  2
# Polynesia                5
# South-easternAsia       11
# SouthAmerica            12
# SouthernAfrica           5
# SouthernAsia             9
# SouthernEurope          12
# WesternAfrica           15
# WesternAsia             18
# WesternEurope            7

# %%
reg = data['Region'].value_counts()
plt.figure(figsize=(16,8))
sns.barplot(x=reg.index,y=reg.values,palette='Set1')
plt.title('Number of Countries by Region',fontweight='bold',fontsize=15)
plt.xlabel('Region',fontsize=12)
plt.ylabel('Count',fontsize=12)
plt.xticks(rotation=90)
plt.yticks(np.arange(0,22,2))
plt.grid()
plt.show()

# %% [markdown]
# ### 4 a). On average which region has the highest GDP per capita (current US$)

# %%
GDP_high=data.groupby("Region")[["GDP per capita (current US$)"]].mean()
GDP_high.sort_values(by="GDP per capita (current US$)",ascending=False)
GDP_high.nlargest(1,"GDP per capita (current US$)")
# Out:
#                  GDP per capita (current US$)
# Region
# NorthernAmerica                       57659.0

# %% [markdown]
# ### 4 b). On average which region has the highest International trade: Imports (million US$)

# %%
ITI_high=data.groupby("Region")[["International trade: Imports (million US$)"]].mean()
ITI_high.sort_values(by="International trade: Imports (million US$)",ascending=False)
ITI_high.nlargest(1,"International trade: Imports (million US$)")
# Out:
#                  International trade: Imports (million US$)
# Region
# NorthernAmerica                                   663552.25

# %% [markdown]
# ### 5. Find out which region has more consistent with respect to GDP per capita (current US$)

# %%
GDP_cons=data.groupby("Region")[["GDP per capita (current US$)"]].std()
GDP_cons.sort_values(by="GDP per capita (current US$)")
# Out:
#                    GDP per capita (current US$)
# Region
# WesternAfrica                        815.095399
# NorthernAfrica                       974.706575
# SouthernAfrica                      2177.551120
# SouthernAsia                        2855.708179
# EasternAfrica                       3716.131770
# CentralAsia                         4152.215490
# CentralAmerica                      4180.440883
# SouthAmerica                        4273.707394
# Micronesia                          4820.669694
# MiddleAfrica                        5274.846281
# EasternEurope                       5415.488739
# Polynesia                           6956.250286
# Oceania                             9233.329638
# SouthernEurope                      9541.703216
# Melanesia                          13855.842686
# Caribbean                          14579.371326
# South-easternAsia                  16311.810656
# WesternAsia                        18812.151459
# ...

# %%
GDP_cons.nsmallest(1,"GDP per capita (current US$)")
# Out:
#                GDP per capita (current US$)
# Region
# WesternAfrica                    815.095399
